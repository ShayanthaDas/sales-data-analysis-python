# %%
import pandas as pd
import io

data = """Date,Product,Region,Sales,Profit
2024-01-01,Laptop,Dhaka,50000,8000
2024-01-02,Mobile,Dhaka,30000,5000
2024-01-03,Laptop,Chittagong,45000,7000
2024-01-04,Tablet,Sylhet,20000,3000
2024-01-05,Mobile,Rajshahi,25000,4000
2024-02-01,Laptop,Dhaka,55000,9000
2024-02-02,Tablet,Khulna,18000,2500
2024-02-03,Mobile,Chittagong,32000,4800
2024-02-04,Laptop,Sylhet,47000,7200
2024-02-05,Mobile,Dhaka,31000,5100"""

df = pd.read_csv(io.StringIO(data))
print(df.head())
# Out:
#          Date Product      Region  Sales  Profit
# 0  2024-01-01  Laptop       Dhaka  50000    8000
# 1  2024-01-02  Mobile       Dhaka  30000    5000
# 2  2024-01-03  Laptop  Chittagong  45000    7000
# 3  2024-01-04  Tablet      Sylhet  20000    3000
# 4  2024-01-05  Mobile    Rajshahi  25000    4000

# %%
import pandas as pd
import matplotlib.pyplot as plt
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-45896f7e-d0da-4866-8f63-1d58449de887" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-45896f7e-d0da-4866-8f63-1d58449de887">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv(list(uploaded.keys())[0])
df.head()
# Out:
#          Date Product      Region  Sales  Profit
# 0  2024-01-01  Laptop       Dhaka  50000    8000
# 1  2024-01-02  Mobile       Dhaka  30000    5000
# 2  2024-01-03  Laptop  Chittagong  45000    7000
# 3  2024-01-04  Tablet      Sylhet  20000    3000
# 4  2024-01-05  Mobile    Rajshahi  25000    4000

# %%
print("Total Sales:", df['Sales'].sum())
print("Total Profit:", df['Profit'].sum())
# Out:
# Total Sales: 353000
# Total Profit: 55600

# %%
region_sales = df.groupby('Region')['Sales'].sum()
print(region_sales)
# Out:
# Region
# Chittagong     77000
# Dhaka         166000
# Khulna         18000
# Rajshahi       25000
# Sylhet         67000
# Name: Sales, dtype: int64

# %%
region_sales.plot(kind='bar')
plt.show()

# %%
df.to_csv("result.csv", index=False)
